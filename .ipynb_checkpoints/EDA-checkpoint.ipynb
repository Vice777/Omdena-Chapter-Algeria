# %% [markdown]
# ## Omdena Chapter: Algeria
# ### Green Algeria Project Building an Intelligent Control System for greenhouses

# %% [markdown]
# <b> <h4> Dataset: <a href="https://www.kaggle.com/datasets/piantic/autonomous-greenhouse-challengeagc-2nd-2019">  Autonomous Greenhouse Challenge(AGC) 2019~2020 - 2nd Edition </a> </h4> </b>
# <br>
#
# Content :
# <br>
# <table style="width:70%">
#     <tr>
#         <th style="width:30%"> File Name </th>
#         <th style="width:70%"> Description </th>
#     </tr>
#     <tr>
#         <td> Weather + Greenhouse-Climate </td>
#         <td> outdoor and indoor greenhouse climate, irrigation, status of actuators,<br> requested and realized climate setpoints </td>
#     </tr>
#     <tr>
#         <td> Resource </td>
#         <td> Resource Consumption </td>
#     </tr>
#     <tr>
#         <td> Production </td>
#         <td> Harvest </td>
#     </tr>
#     <tr>
#         <td> Crop-Production </td>
#         <td> Crop-related parameters </td>
#     </tr>
#     <tr>
#         <td> TomQuality </td>
#         <td> Tomato Quality </td>
#     </tr>
#     <tr>
#         <td> LabAnalysis </td>
#         <td> Analysis of irrigation and drain samples </td>
#     </tr>
#     <tr>
#         <td> Grodan-Sens </td>
#         <td> Root-zone/slab information </td>
#     </tr>
# </table>

# %%
# This file covers the harvest analysis Greenhouse
# The weather & internal climates are covered in separate file

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
path = ("./Dataset")
os.listdir(path)
# Out:
# ['AICU',
#  'Automatoes',
#  'Digilog',
#  'Economics.pdf',
#  'IUACAAS',
#  'ReadMe.pdf',
#  'Reference',
#  'TheAutomators',
#  'Weather']

# %%
files = ['AICU', 'Automatoes', 'Digilog', 'IUACAAS', 'Reference', 'TheAutomators']

# %%
dataframe = {}
for file in files:
    dataframe[file] = pd.read_csv("./Dataset/"+file+"/CropParameters.csv")

# %%
for i in dataframe:
    print(i,"\n",dataframe[i].head(),"\n")
# Out:
# AICU
#     %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  43823       18.7         8.3          NaN         3.6         1.8
# 1  43830       29.9        11.7          1.3         3.6         1.8
# 2  43838       35.8        13.6          3.2         3.6         1.8
# 3  43845       35.1        13.5          4.7         3.6         1.8
# 4  43852       34.7        12.6          5.8         3.6         1.8
#
# Automatoes
#     %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  43823       14.5         8.1          NaN         3.9        1.95
# 1  43830       29.5        10.8          1.3         3.9        1.95
# 2  43838       37.4        12.8          3.0         3.9        1.95
# 3  43845         34        12.5          4.7         3.9        1.95
# 4  43852       34.7        10.9          5.9         3.9        1.95
#
# Digilog
#     %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  43823         15         8.0          NaN         2.6         1.3
# 1  43830       20.5        10.6          1.0         2.6         1.3
# 2  43838       28.1        13.2          2.9         2.6         1.3
# 3  43845       35.9        13.5          4.3         2.6         1.3
# 4  43852       33.3        12.1          5.8         3.9         1.3
#
# IUACAAS
#     %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  43823       19.5         8.0          NaN         3.9        1.95
# 1  43830       26.6        10.2          0.9         3.9        1.95
# 2  43838       32.2        11.9          2.3         3.9        1.95
# 3  43845       27.2        12.2          3.8         3.9        1.95
# 4  43852       29.9        12.7          5.0         3.9        1.95
#
# Reference
#     %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  43823       14.2         7.2          NaN         NaN         1.4
# 1  43830       26.6         9.6          1.2         4.0         1.4
# 2  43838       35.9        12.0          3.1         4.0         1.4
# 3  43845       33.1        11.8          4.7         4.0         1.4
# 4  43852       38.8        11.3          6.0         4.0         1.4
#
# TheAutomators
#     %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  43823       14.4         7.1          NaN         3.6         1.8
# 1  43830       27.9        10.5          0.9         3.6         1.8
# 2  43838       32.8        12.8          2.8         3.6         1.8
# 3  43845       30.2        12.8          4.0         3.6         1.8
# 4  43852       30.3        12.5          5.2         4.5         1.8

# %%
for i in dataframe:
    dataframe[i]['%Time'] = pd.to_datetime(dataframe[i]['%Time'], unit='d',origin='1899-12-30')

# %%
for i in dataframe:
    
    print(i,"\n",dataframe[i],"\n")
# Out:
# AICU
#          %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  2019-12-24       18.7    8.300000    12.516667         3.6         1.8
# 1  2019-12-31       29.9   11.700000     1.300000         3.6         1.8
# 2  2020-01-08       35.8   13.600000     3.200000         3.6         1.8
# 3  2020-01-15       35.1   13.500000     4.700000         3.6         1.8
# 4  2020-01-22       34.7   12.600000     5.800000         3.6         1.8
# 5  2020-01-29       32.4   11.300000     6.900000         3.6         1.8
# 6  2020-02-05       29.4   10.900000     8.100000         3.6         1.8
# 7  2020-02-12       30.8   10.700000     9.200000         3.6         1.8
# 8  2020-02-19       29.1   11.300000    10.400000         3.6         1.8
# 9  2020-02-26       36.5   11.200000    11.600000         3.6         1.8
# 10 2020-03-04       33.9   10.600000    13.100000         3.6         1.8
# 11 2020-03-11       36.5   11.700000    14.500000         3.6         1.8
# 12 2020-03-18       33.7   11.300000    15.900000         4.5         1.8
# 13 2020-03-25       35.8   11.400000    17.100000         4.5         1.8
# 14 2020-04-01       34.9   11.700000    18.500000         4.5         1.8
# 15 2020-04-08       35.7   11.300000    19.700000         4.5         1.8
# 16 2020-04-15       30.3   10.800000    21.300000         4.5         1.8
# 17 2020-04-22         14    9.800000    22.000000         4.5         1.8
# 18 2020-04-29        NaN   11.316667    22.000000         4.5         1.8
# 19 2020-05-06        NaN   11.316667    12.516667         4.5         1.8
# 20 2020-05-13        NaN   11.316667    12.516667         4.5         1.8
# 21 2020-05-20        NaN   11.316667    12.516667         4.5         1.8
# 22 2020-05-27        NaN   11.316667    12.516667         4.5         1.8
#
# Automatoes
#          %Time Stem_elong  Stem_thick  Cum_trusses  stem_dens   plant_dens
# 0  2019-12-24       14.5    8.100000    12.694444        3.90        1.95
# 1  2019-12-31       29.5   10.800000     1.300000        3.90        1.95
# 2  2020-01-08       37.4   12.800000     3.000000        3.90        1.95
# 3  2020-01-15         34   12.500000     4.700000        3.90        1.95
# 4  2020-01-22       34.7   10.900000     5.900000        3.90        1.95
# 5  2020-01-29       36.2   11.400000     6.900000        3.90        1.95
# 6  2020-02-05       32.4   10.600000     7.900000        3.90        1.95
# 7  2020-02-12       37.2   11.100000     9.300000        3.90        1.95
# 8  2020-02-19       39.3   11.700000    10.200000         5.4         1.8
# 9  2020-02-26       36.6   10.800000    11.400000         5.4         1.8
# 10 2020-03-04       34.4   11.700000    12.700000         5.4         1.8
# 11 2020-03-11         36   12.000000    14.100000         5.4         1.8
# 12 2020-03-18       32.5   10.900000    15.500000         5.4         1.8
# 13 2020-03-25       35.6   11.100000    16.900000         5.4         1.8
# 14 2020-04-01       29.4   10.300000    18.100000         5.4         1.8
# 15 2020-04-08       31.5   10.400000    19.600000         5.4         1.8
# 16 2020-04-15       31.9    9.900000    20.800000         5.4         1.8
# 17 2020-04-22       32.2    9.600000    22.200000         5.4         1.8
# 18 2020-04-29        NaN   11.011111    23.800000         5.4         1.8
# 19 2020-05-06        NaN   11.011111    12.311111         5.4         1.8
# 20 2020-05-13        NaN   11.011111    12.311111         5.4         1.8
# 21 2020-05-20        NaN   11.011111    12.311111         5.4         1.8
# 22 2020-05-27        NaN   11.011111    12.311111         5.4         1.8

# %%
 column = dataframe['AICU'].columns

# %%
for i in dataframe:
    print(i)
# Out:
# AICU
# Automatoes
# Digilog
# IUACAAS
# Reference
# TheAutomators

# %%
#as the given data is in time-series format therefor interpolating the data with nearest member to remove null values

for i in dataframe:
    dataframe[i]['Stem_elong'] = dataframe[i]['Stem_elong'].astype(str).astype(float)
    

for i in dataframe:
    print(i, dataframe[i].mean())
    
    #dataframe[i] = dataframe[i].fillna(dataframe[i].mean())
# Out:
# AICU Stem_elong     31.511111
# Stem_thick     11.316667
# Cum_trusses    12.516667
# stem_dens       4.030435
# plant_dens      1.800000
# dtype: float64
# Automatoes Stem_elong     33.594444
# Stem_thick     10.838889
# Cum_trusses    12.694444
# stem_dens       4.747826
# plant_dens      1.950000
# dtype: float64
# Digilog Stem_elong     29.266667
# Stem_thick     10.961111
# Cum_trusses    11.994444
# stem_dens       4.069565
# plant_dens      1.300000
# dtype: float64
# IUACAAS Stem_elong     31.344444
# Stem_thick     10.744444
# Cum_trusses    11.916667
# stem_dens       4.486957
# plant_dens      1.950000
# dtype: float64
# Reference Stem_elong     31.761111
# Stem_thick     10.150000
# Cum_trusses    13.161111
# stem_dens       5.272727
# plant_dens      1.400000
# dtype: float64
# TheAutomators Stem_elong     32.366667
# Stem_thick     11.011111
# Cum_trusses    12.311111
# stem_dens       4.969565
# plant_dens      1.800000
# dtype: float64
# C:\Users\vivek\AppData\Local\Temp\ipykernel_26516\2750603118.py:8: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.

# %%
plt.figure(figsize=(10,10))
for i in dataframe:
    plt.plot(dataframe[i]["%Time"], dataframe[i]["Stem_elong"])
plt.legend(files)
plt.title("Stem_elong vs Time")
plt.xlabel("Time")
plt.ylabel("Stem_elong")
plt.show()

# %%
dataframe['AICU']['Stem_elong']
# Out:
# 0      18.7
# 1      29.9
# 2      35.8
# 3      35.1
# 4      34.7
# 5      32.4
# 6      29.4
# 7      30.8
# 8      29.1
# 9      36.5
# 10     33.9
# 11     36.5
# 12     33.7
# 13     35.8
# 14     34.9
# 15     35.7
# 16     30.3
# 17       14
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# Name: Stem_elong, dtype: object

# %%
data1 = dataframe['AICU']['Stem_elong']

# %%
data1 = data1.astype(str).astype(float)

# %%
data1.mean()
# Out:
# 31.511111111111106
